# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from scipy.spatial.distance import cdist
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 from sklearn.preprocessing import MinMaxScaler
#       4 from sklearn.cluster import KMeans
#       5 from sklearn.metrics import silhouette_score
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
NUM_CLUSTERS = 2
RANDOM_STATE = 42

# %%
labels = KMeans(n_clusters=NUM_CLUSTERS, n_init=20).fit_predict(points)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 labels = KMeans(n_clusters=NUM_CLUSTERS, n_init=20).fit_predict(points)
#
# NameError: name 'KMeans' is not defined

# %%
data = pd.read_csv("../data/data_device.csv")

# Drop CPU (threads) column - index 0
raw_points = np.delete(data.values, 0, axis=1)

# %%
scaler = MinMaxScaler()
points_norm = scaler.fit_transform(raw_points)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 scaler = MinMaxScaler()
#       2 points_norm = scaler.fit_transform(raw_points)
#
# NameError: name 'MinMaxScaler' is not defined

# %%
FEATURE_INDEX = {
    "Total Ram": 0,
    "Storage": 1,
    "Internet": 2,
    "Core": 3
}

WEIGHTS = {
    "Core": 1.4,
    "Total Ram": 1.2,
    "Internet": 1.1,
    "Storage": 0.65,
}

points = points_norm.copy()

for feat, w in WEIGHTS.items():
    idx = FEATURE_INDEX[feat]
    points[:, idx] *= w
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 15
#       1 FEATURE_INDEX = {
#       2     "Total Ram": 0,
#       3     "Storage": 1,
#       4     "Internet": 2,
#       5     "Core": 3
#       6 }
#       8 WEIGHTS = {
#       9     "Core": 1.4,
#      10     "Total Ram": 1.2,
#      11     "Internet": 1.1,
#      12     "Storage": 0.65,
#      13 }
# ---> 15 points = points_norm.copy()
#      17 for feat, w in WEIGHTS.items():
#      18     idx = FEATURE_INDEX[feat]
#
# NameError: name 'points_norm' is not defined

# %%
kmeans = KMeans(
    n_clusters=NUM_CLUSTERS,
    init="k-means++",
    n_init=20,
    random_state=RANDOM_STATE
)

labels = kmeans.fit_predict(points)

centroids = kmeans.cluster_centers_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 kmeans = KMeans(
#       2     n_clusters=NUM_CLUSTERS,
#       3     init="k-means++",
#       4     n_init=20,
#       5     random_state=RANDOM_STATE
#       6 )
#       8 labels = kmeans.fit_predict(points)
#      10 centroids = kmeans.cluster_centers_
#
# NameError: name 'KMeans' is not defined

# %%
dist_matrix = cdist(points, centroids)
nearest_idx = np.argmin(dist_matrix, axis=0)

final_centers = points[nearest_idx]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dist_matrix = cdist(points, centroids)
#       2 nearest_idx = np.argmin(dist_matrix, axis=0)
#       4 final_centers = points[nearest_idx]
#
# NameError: name 'cdist' is not defined

# %%
clusters = []

for i in range(NUM_CLUSTERS):
    clusters.append(points[labels == i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 clusters = []
#       3 for i in range(NUM_CLUSTERS):
# ----> 4     clusters.append(points[labels == i])
#
# NameError: name 'points' is not defined
